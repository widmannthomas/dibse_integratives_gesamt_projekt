# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (30,10)

# %% [markdown]
# # read the measurements file

# %%
data_frame = pd.read_csv("test.csv", sep=" ", names=["time_ms", "current_mA"])
data_frame.describe()
# Out:
#             time_ms    current_mA
# count  11609.000000  11609.000000
# mean   15489.912051     30.197491
# std     9022.009924     37.823376
# min       14.000000      0.013640
# 25%     7612.000000      0.027270
# 50%    15490.000000      0.031820
# 75%    23264.000000     76.900000
# max    31188.000000    145.454540

# %% [markdown]
# # WiFi connect cycle

# %%
plt.plot(data_frame[2500:5500].current_mA, label="Connection cycle [mA]")
plt.legend()
plt.show()

# %% [markdown]
# # Deep sleep power consumption

# %%
plt.plot(data_frame.current_mA[100:400], label="deep sleep [mA]")
plt.plot(data_frame.current_mA[100:400].rolling(30).mean(), label="moving average [mA]")
plt.legend()
plt.show()

# %% [markdown]
# # Wake up phase

# %%
plt.plot(data_frame.current_mA[2900:3100], label="deep sleep [mA]")
plt.legend()
plt.show()

# %% [markdown]
# Power up using dynamic IP

# %%
data_frame_dynamic_ip = pd.read_csv("dynamic_ip.csv", sep=" ", names=["time_ms", "current_mA"])
data_frame_dynamic_ip.describe()
# Out:
#              time_ms    current_mA
# count   14820.000000  14820.000000
# mean   287250.002632     56.004696
# std     11796.308497     28.887264
# min    266817.000000    -10.418180
# 25%    277031.250000     68.231820
# 50%    287253.500000     68.677270
# 75%    297464.750000     69.336360
# max    307689.000000    145.454540

# %%
start=5354
end=7338
duration=end-start
plt.plot(data_frame_dynamic_ip.current_mA[5334:7358], label="Power up phase with dynamic IP [mA]")
#plt.plot(data_frame_dynamic_ip.current_mA, label="Power up phase with dynamic IP [mA]")
plt.legend()
plt.show()
print("Duration of one cycle: ",duration,"ms")
# Out:
# Duration of one cycle:  1984 ms

# %%
data_frame_static_ip_test = pd.read_csv("static_ip.csv", sep=" ", names=["time_ms", "current_mA"])
data_frame_static_ip_test.describe()
# Out:
#             time_ms    current_mA
# count  13560.000000  13559.000000
# mean   51863.394395     46.916368
# std    11322.117722     32.815881
# min       70.000000    -11.022730
# 25%    43119.250000      0.045450
# 50%    52269.500000     68.400000
# 75%    61401.500000     69.177270
# max    70566.000000    145.454540

# %%
start=1630
end=3132
duration=end-start
plt.plot(data_frame_static_ip_test.current_mA[1650:3692], label="Power up phase with static IP [mA]")
#plt.plot(data_frame_static_ip_test.current_mA, label="Power up phase with static IP [mA]")
plt.legend()
plt.show()
print("Duration of one cycle: ", duration, "ms")
# Out:
# Duration of one cycle:  1502 ms
